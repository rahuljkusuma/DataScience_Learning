# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data_p5.csv')

# %%
# data.head()

# %%
ages = data['Age']
dev_sal = data['All_Devs']
py_sal = data['Python']
js_sal = data['JavaScript']

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.legend()
plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

plt.fill_between(ages, py_sal, alpha=0.25)

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, overall_median, alpha=0.25)

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, overall_median,
                 where=(py_sal>overall_median),
                 interpolate=True,
                 alpha=0.25)

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, overall_median,
                 where=(py_sal>overall_median),
                 interpolate=True,
                 alpha=0.25)


plt.fill_between(ages, py_sal, overall_median,
                 where=(py_sal<=overall_median),
                 interpolate=True,
                 alpha=0.25)


plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, overall_median, color='green',
                 where=(py_sal>overall_median),
                 interpolate=True,
                 alpha=0.25)


plt.fill_between(ages, py_sal, overall_median, color='red',
                 where=(py_sal<=overall_median),
                 interpolate=True,
                 alpha=0.25)


plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, dev_sal, color='green',
                 where=(py_sal>dev_sal),
                 interpolate=True,
                 alpha=0.25)


plt.fill_between(ages, py_sal, dev_sal, color='red',
                 where=(py_sal<=dev_sal),
                 interpolate=True,
                 alpha=0.25)


plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

# %%
plt.plot(ages, dev_sal, color='#444444', linestyle='--', label='All Devs')
plt.plot(ages, py_sal, label='Python')

overall_median = 57287

plt.fill_between(ages, py_sal, dev_sal, color='green', label='Above Avg',
                 where=(py_sal>dev_sal),
                 interpolate=True,
                 alpha=0.25)


plt.fill_between(ages, py_sal, dev_sal, color='red', label='Below Avg',
                 where=(py_sal<=dev_sal),
                 interpolate=True,
                 alpha=0.25)


plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()
