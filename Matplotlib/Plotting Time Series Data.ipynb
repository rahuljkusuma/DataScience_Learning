# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
plt.style.use('seaborn')

# %%
# data = pd.read_csv('data.csv')
# price_date = data['Date']
# price_close = data['Close']

# plt.title('Bitcoin Prices')
# plt.xlabel('Date')
# plt.ylabel('Closing Price')

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

# %%
plt.plot_date(dates, y)

plt.tight_layout()

# %%
plt.plot_date(dates, y, linestyle='solid')

plt.tight_layout()

# %%
plt.plot_date(dates, y, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.tight_layout()

# %%
plt.plot_date(dates, y, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.tight_layout()

# %%
plt.plot_date(dates, y, linestyle='solid')

plt.gcf().autofmt_xdate() #Date alignment

date_format = mpl_dates.DateFormatter('%b, %d, %Y') #Defining date format

plt.gca().xaxis.set_major_formatter(date_format) #Asigning date format to graph

plt.tight_layout()

# %%
mpl_dates.DateFormatter('%H, %M, %S')

# %% [markdown]
# ## Data Analysis

# %%
df = pd.read_csv('data_p8.csv')
# df.head()

# %%
price_date = df.Date
price_close = df.Close

# %%
plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate() #Date alignment

# date_format = mpl_dates.DateFormatter('%b, %d, %Y') #Defining date format

# plt.gca().xaxis.set_major_formatter(date_format) #Asigning date format to graph

plt.tight_layout()

# %%
#Below graph will not show May-17th data on last instead of first

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate() #Date alignment

# date_format = mpl_dates.DateFormatter('%b, %d, %Y') #Defining date format

# plt.gca().xaxis.set_major_formatter(date_format) #Asigning date format to graph

plt.tight_layout()

# %%
df = pd.read_csv('data_p8.csv')

df.Date = pd.to_datetime(df.Date)
df.sort_values('Date', inplace=True) #Sorting dates to plot graph in sequence

price_date = df.Date
price_close = df.Close

# %%
plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate() #Date alignment

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
